# %% [markdown]
# 1. Provide options which dataset/forest to load
# 2. Precompute maps and cable roads
# 3. Set A-Value, slope, etc.
# 4. Provide pre-computed optimized results
# 5. Editor
#    - top layout
#    - Pareto frontier
#    - Current layout properties
# 6. Export? to exact positions of tree

# %%
# ignore the nopython dependency warning, as it cant be fixed with current dependencies
import warnings

warnings.filterwarnings("ignore", message=".*The 'nopython' keyword.*")

# Package Imports
import pandas as pd
import geopandas as gpd

import matplotlib.pyplot as plt

from shapely.geometry import LineString, Polygon, Point

import pickle

# Importing my modules
from src.main import data_loading, plotting_2d

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# #### Preprocessing

# %%
# # Load, preprocess and save the dataframe with the corresponding number - only needed to do once
# data_loading.load_and_preprocess_raw_data(data_to_load=3)

# %%
# tree_gdf, height_gdf = data_loading.load_processed_gdfs(data_to_load=3)

# %% [markdown]
# #### Area-Specific Setup

# %%
# # create coordinates for each dataframe with the corresponding upper and lower anchors
# coords = []
# fig, ax = plt.subplots()
# ax.set_xlabel("X coordinate", fontsize=15)
# ax.set_ylabel("Y coordinate", fontsize=15)
# ax.scatter(tree_gdf["x"], tree_gdf["y"])

# cid = fig.canvas.mpl_connect(
#     "button_press_event", lambda event: plotting_2d.onclick(event, coords)
# )

# %%
# # manually insert those coordinates
# # recorded coordinates for the given areas
# downhill_anchors = Polygon(
#     [
#         Point(xy)
#         for xy in [
#             (-123.88268627035482, 83.05479790035122),
#             (-74.89307684787903, 138.5299549848453),
#             (-21.10056454084676, 161.97821725767267),
#             (-6.051468835903222, 148.2524051955298),
#             (-60.16417466857257, 116.79741921978575),
#             (-115.23746107815322, 64.75371515082742),
#         ]
#     ]
# )
# uphill_anchors = Polygon(
#     [
#         Point(xy)
#         for xy in [
#             (-55.04107825837903, -15.31352187833928),
#             (-17.578435758838708, -17.601157222029755),
#             (4.194723984483858, -1.5877098161964227),
#             (30.450593086725803, -30.18315161232738),
#             (-11.49475877173387, -41.04941949485714),
#             (-58.5632070403871, -38.189875315244045),
#         ]
#     ]
# )
# # road = LineString([(-57.282432937838706, -17.029248386107135), (-34.86888614324194, -21.604519073488092), (-15.337081079379033, -15.31352187833928), (-0.2879853744354932, -7.878707011345227), (12.51975565104837, 6.990922722642864), (19.884206740701615, 21.86055245663097)])
# # road = LineString([(-59.52378761729838, -12.453977698726185), (-41.91314370725806, -13.597795370571419), (-18.218822810112897, -10.16634235503571), (3.2341434075725886, 0.12801669157144602), (15.401497381782264, 23.576278964398824), (17.00246500996775, 26.43582314401192)])
# road = LineString(
#     [
#         (-89.6286010742188, -24.4624996185303),
#         (-69.618896484375, -20.364200592041),
#         (-41.314998626709, -13.9251003265381),
#         (-29.2644004821777, -8.47910022735596),
#         (-20.2950000762939, -3.67030000686646),
#         (-15.375, -0.148599997162819),
#         (-6.49030017852783, 2.74860000610352),
#         (0.943400025367737, 3.86450004577637),
#         (15.1605997085571, -0.302300006151199),
#         (29.3377990722656, -3.47709989547729),
#     ]
# )

# inner_forest = Polygon(
#     [
#         Point(xy)
#         for xy in [
#             (-105.43005197808363, 62.73802056488026),
#             (-10.557896233758669, 146.34023494632802),
#             (13.160142702322588, 51.07259530235265),
#             (8.890895693827957, 9.27148811162877),
#             (-55.62217021231302, -10.17088732591722),
#             (-81.71201304200238, 18.992675830401765),
#         ]
#     ]
# )

# extra_geometry_gpd = gpd.GeoDataFrame(
#     pd.DataFrame(
#         {
#             "name": ["uphill_anchors", "road", "downhill_anchors", "inner_forest"],
#             "geometry": [uphill_anchors, road, downhill_anchors, inner_forest],
#         }
#     )
# )

# # set the name as index to easily select the geometry
# extra_geometry_gpd.set_index("name", inplace=True)
# extra_geometry_gpd.loc["road"]

# # plotting.plot_gdfs([tree_gdf,extra_geometry_gpd])
# Out:
# /home/carlo/GitHub/MultiObjectOptimizationCableYarding/moo_env/lib/python3.10/site-packages/pandas/core/dtypes/cast.py:122: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)
# geometry    LINESTRING (-89.62860 -24.46250, -69.61890 -20...
# Name: road, dtype: geometry

# %%
# from src.main import classes_cable_road_computation

# # create a class instance of the forest area with all the necessary attributes
# forest_area_3 = classes_cable_road_computation.forest_area(
#     tree_gdf, height_gdf, extra_geometry_gpd
# )

# %% [markdown]
# #### Compute the cable roads

# %%
# and the forest_area_3
pkl_file = open("forest_area_3.pkl", "rb")
forest_area_3 = pickle.load(pkl_file)

# %%
# Readjusting the mdm computation and the corresponding euler knicklastforces

from src.main import mechanical_computations

forest_area_3.tree_gdf["middle_height"] = forest_area_3.tree_gdf[
    "diameter_series"
].apply(lambda x: len(x) // 2)
# and the corresponding diameter there
forest_area_3.tree_gdf["mdm"] = forest_area_3.tree_gdf.apply(
    lambda x: x["diameter_series"][x["middle_height"]], axis=1
)

# get the euler forces
list_of_euler_max_force_lists = []
for index, row in forest_area_3.tree_gdf.iterrows():
    temp_list = [
        mechanical_computations.euler_knicklast(row["mdm"], height * 2)
        for height in row["height_series"]
    ]
    list_of_euler_max_force_lists.append(temp_list)

forest_area_3.tree_gdf["max_supported_force_series"] = list_of_euler_max_force_lists

# %%
forest_area_3.compute_cable_road()
# Out:
# 2304  candidates initially
# 2278  after slope deviations
# 1388  after supports trees
# 75  after possible anchor triples
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 85000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 7079.355439383741
# force on support right 6223.745991441057
# max supported force 339571.2084915763
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 85000.0
# checking if no collisions overall line
# Found no collisions
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 85000.0
# checking if no collisions overall line
# Found no collisions
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 85000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 9107.52209152448
# force on support right 7927.194846320988
# max supported force 169038.89432920673
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 85000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 13633.410630261384
# force on support right 13428.189225687245
# max supported force 55689.228509950764
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 6643.286259760816
# force on support right 5658.440357439529
# max supported force 40914.53523180056
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 4804.850061304183
# force on support right 4386.884026623351
# max supported force 31325.191036847304
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 85000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 6728.930044267531
# force on support right 5525.083747801184
# max supported force 169038.89432920673
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 85000.0
# checking if no collisions overall line
# Found no collisions
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 85000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 10608.594231782543
# force on support right 9478.30587351984
# max supported force 2165.961296676192
# Support withstands tension: False
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# segment is infesible
# raising height to  6
# checking if support withstands tension
# force on support left 11816.896623332956
# force on support right 10578.162182513348
# max supported force 18663.443365175768
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 85000.0
# checking if no collisions overall line
# Found no collisions
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 85000.0
# checking if no collisions overall line
# Found no collisions
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 85000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 4564.362465898395
# force on support right 4370.176633116236
# max supported force 1700.6645640285274
# Support withstands tension: False
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# segment is infesible
# raising height to  6
# checking if support withstands tension
# force on support left 5735.080605818606
# force on support right 5813.576125500275
# max supported force 239186.65482151142
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 6137.191579880249
# force on support right 5608.249697661265
# max supported force 175728.9708892737
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 9008.73823666002
# force on support right 7751.727086465715
# max supported force 134542.49333710017
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 12452.957458616476
# force on support right 10523.580875697724
# max supported force 106305.17992067174
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 85000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 4520.501117164096
# force on support right 3656.0338921864045
# max supported force 48182.46997685301
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 85000.0
# checking if no collisions overall line
# Found no collisions
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 55000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 55000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 4835.387375795081
# force on support right 5349.533883131809
# max supported force 267234.6758504002
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 2392.020635856662
# force on support right 2631.785342065012
# max supported force 196335.68021662053
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 3220.0876235861588
# force on support right 2318.4804967257937
# max supported force 150319.5051658501
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 5198.108805646375
# force on support right 3658.2633342945715
# max supported force 118770.9670446223
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  10
# checking if support withstands tension
# force on support left 7402.906522007367
# force on support right 5593.49770150028
# max supported force 96204.48330614406
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  11
# checking if support withstands tension
# force on support left 9635.259699007433
# force on support right 7707.477971298231
# max supported force 79507.83744309426
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  12
# checking if support withstands tension
# force on support left 11842.989259200122
# force on support right 9900.84598310766
# max supported force 66808.66896260004
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 55000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 55000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 4784.359357738897
# force on support right 5132.294569100535
# max supported force 164937.83402088986
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 3133.360336443719
# force on support right 3041.6265953875354
# max supported force 121178.81683167418
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 4039.5506093959384
# force on support right 3152.5287499155675
# max supported force 92777.53163675054
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 5830.099998762191
# force on support right 4425.044294161935
# max supported force 73305.70400928438
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  10
# checking if support withstands tension
# force on support left 7877.175754298207
# force on support right 6202.892116529019
# max supported force 59377.62024752035
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  11
# checking if support withstands tension
# force on support left 9985.33138525307
# force on support right 8179.205586777632
# max supported force 49072.41342770277
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 55000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 55000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 5883.96859281488
# force on support right 6081.057974075989
# max supported force 15086.182063388504
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 6026.777890535689
# force on support right 5343.431944140836
# max supported force 11083.725597591554
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 8723.378096884504
# force on support right 6973.639351595913
# max supported force 8485.977410656033
# Support withstands tension: False
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# segment is infesible
# raising height to  6
# checking if support withstands tension
# force on support left 5858.440889739892
# force on support right 5512.038820085026
# max supported force 89238.10880537571
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 9052.425356763992
# force on support right 8545.463262155114
# max supported force 65562.69218354134
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 13609.22291788904
# force on support right 11540.426708002136
# max supported force 50196.43620302383
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 18087.483499680322
# force on support right 14703.75405445261
# max supported force 39661.38169127809
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  10
# checking if support withstands tension
# force on support left 22204.134464393017
# force on support right 17870.432580446162
# max supported force 32125.719169935255
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 55000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 55000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 5615.097787553505
# force on support right 5867.3268606866
# max supported force 15086.182063388504
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 3854.2962949009006
# force on support right 3557.91503116826
# max supported force 11083.725597591554
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 5571.952218991567
# force on support right 4421.118835361746
# max supported force 8485.977410656033
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 8361.787060458719
# force on support right 6238.181104978106
# max supported force 6704.969805950446
# Support withstands tension: False
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# segment is infesible
# raising height to  6
# checking if support withstands tension
# force on support left 1749.9856871432803
# force on support right 1080.7980937876903
# max supported force 105010.14792787982
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 5300.652006970783
# force on support right 3994.1435135457023
# max supported force 77150.31276334028
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 7810.563508575772
# force on support right 6071.7835277328495
# max supported force 59068.2082094324
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 55000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 55000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 4425.468784829397
# force on support right 3813.206990321551
# max supported force 37710.982602063465
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 8539.891116554329
# force on support right 7812.913997357123
# max supported force 27706.028034169074
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 12150.14513585744
# force on support right 10283.727710135661
# max supported force 21212.427713660698
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 15623.24080634775
# force on support right 12797.06305060812
# max supported force 16760.436712028208
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  10
# checking if support withstands tension
# force on support left 18895.826099725287
# force on support right 15311.75043798668
# max supported force 13575.953736742847
# Support withstands tension: False
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# segment is infesible
# segment is infesible
# raising height to  6
# checking if support withstands tension
# force on support left 2223.9478019797
# force on support right 2816.4564905656684
# max supported force 95551.31188681266
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 2096.2424280602936
# force on support right 1188.0628463547243
# max supported force 70200.9638352093
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 4436.563305673462
# force on support right 3023.6188321087843
# max supported force 53747.61293633212
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 6809.143665162063
# force on support right 5095.6524076148435
# max supported force 42467.24972747229
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  10
# checking if support withstands tension
# force on support left 9140.583286543593
# force on support right 7222.101457387611
# max supported force 34398.47227925256
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  11
# checking if support withstands tension
# force on support left 11417.324685808475
# force on support right 9379.535975202105
# max supported force 28428.489486985585
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  12
# checking if support withstands tension
# force on support left 13634.930179512672
# force on support right 11560.393971827374
# max supported force 23887.827971703166
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  13
# checking if support withstands tension
# force on support left 15791.722616098876
# force on support right 13760.549112641198
# max supported force 20354.12560902518
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  14
# checking if support withstands tension
# force on support left 17887.262118639454
# force on support right 15976.858704790644
# max supported force 17550.240958802326
# Support withstands tension: False
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# segment is infesible
# raising height to  6
# checking if support withstands tension
# force on support left 3070.6709444642393
# force on support right 3614.240836129089
# max supported force 755535.3567217827
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 1954.5846128543965
# force on support right 1462.8753938122147
# max supported force 555087.20085682
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 3830.2028885165378
# force on support right 2546.153108411357
# max supported force 424988.63815600274
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 5989.127747306984
# force on support right 4436.861054805221
# max supported force 335793.49187634786
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  10
# checking if support withstands tension
# force on support left 8169.74462931709
# force on support right 6488.859345751942
# max supported force 271992.7284198418
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  11
# checking if support withstands tension
# force on support left 10325.434862271255
# force on support right 8607.020095443595
# max supported force 224787.37885937336
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  12
# checking if support withstands tension
# force on support left 12441.8897759137
# force on support right 10766.95939392775
# max supported force 188883.83918044568
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  13
# checking if support withstands tension
# force on support left 14513.276273227424
# force on support right 12958.7560560348
# max supported force 160942.44285197736
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  14
# checking if support withstands tension
# force on support left 16536.89605813579
# force on support right 15176.711664522138
# max supported force 138771.800214205
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# segment is infesible
# raising height to  6
# checking if support withstands tension
# force on support left 3377.2850632508757
# force on support right 3460.326490952659
# max supported force 75472.93826941977
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 6970.884892630082
# force on support right 4036.1005263914108
# max supported force 55449.50566732881
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 9272.659168824119
# force on support right 6806.960839896818
# max supported force 42453.527776548624
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 11635.886592526032
# force on support right 10219.409352687157
# max supported force 33543.52811974212
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  10
# checking if support withstands tension
# force on support left 14002.063048452337
# force on support right 13946.983996852203
# max supported force 27170.25777699112
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  11
# checking if support withstands tension
# force on support left 16344.321238023156
# force on support right 17892.386657125953
# max supported force 22454.75849338109
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  12
# checking if support withstands tension
# force on support left 18648.27012515145
# force on support right 22002.069878348426
# max supported force 18868.234567354943
# Support withstands tension: False
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# segment is infesible
# raising height to  6
# checking if support withstands tension
# force on support left 8397.824302474604
# force on support right 7505.513076695162
# max supported force 203184.59240065888
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 18904.79580240785
# force on support right 10328.566167568188
# max supported force 149278.47604946367
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 22864.385235806014
# force on support right 17221.707336147003
# max supported force 114291.33322537062
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 26600.73999154691
# force on support right 25817.809168692456
# max supported force 90304.26328918172
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  10
# checking if support withstands tension
# force on support left 30020.978273597186
# force on support right 35082.40576779171
# max supported force 73146.45326423719
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  11
# checking if support withstands tension
# force on support left 33081.512365534574
# force on support right 44232.03317660446
# max supported force 60451.61426796462
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  12
# checking if support withstands tension
# force on support left 35773.327310644134
# force on support right 52635.381369394745
# max supported force 50796.14810016472
# Support withstands tension: False
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# segment is infesible
# raising height to  6
# checking if support withstands tension
# force on support left 11939.655946258867
# force on support right 12556.168588876786
# max supported force 233944.57888220905
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 3522.200368124948
# force on support right 6366.672215378917
# max supported force 171877.64979101074
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 6925.7043299841325
# force on support right 3769.0240203990065
# max supported force 131593.8256212426
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 12076.932339116533
# force on support right 11198.320415841697
# max supported force 103975.36839209292
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  10
# checking if support withstands tension
# force on support left 17320.074851592894
# force on support right 21071.52042156736
# max supported force 84220.04839759527
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  11
# checking if support withstands tension
# force on support left 22320.16642804311
# force on support right 31876.70944202105
# max supported force 69603.34578313658
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  12
# checking if support withstands tension
# force on support left 26922.747784597694
# force on support right 42639.12810872481
# max supported force 58486.14472055226
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  13
# checking if support withstands tension
# force on support left 31053.284205381195
# force on support right 52435.43709288092
# max supported force 49834.34816425755
# Support withstands tension: False
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# segment is infesible
# raising height to  6
# checking if support withstands tension
# force on support left 11595.018706961604
# force on support right 8665.470181115092
# max supported force 1999744.0493814608
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 53219.51359969494
# force on support right 27272.086205558557
# max supported force 1469199.7097496446
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 55167.06087547112
# force on support right 50457.49638545151
# max supported force 1124856.0277770718
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 56695.71998280549
# force on support right 67540.0857661508
# max supported force 888775.133058427
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  10
# checking if support withstands tension
# force on support left 57960.5152865998
# force on support right 77589.86752150522
# max supported force 719907.8577773259
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  11
# checking if support withstands tension
# force on support left 59047.91572269895
# force on support right 83473.99899645969
# max supported force 594965.1717167982
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  12
# checking if support withstands tension
# force on support left 60009.536349053815
# force on support right 87166.77255818012
# max supported force 499936.0123453652
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  13
# checking if support withstands tension
# force on support left 62381.499052733525
# force on support right 89662.1904792118
# max supported force 425980.9809333289
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  14
# checking if support withstands tension
# force on support left 67962.75454747518
# force on support right 91457.20474039523
# max supported force 367299.92743741116
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# segment is infesible
# didnt find suitable candidate - select first candidate as support and iterate
# raising height to  6
# checking if support withstands tension
# force on support left 4425.468784829397
# force on support right 3813.206990321551
# max supported force 37710.982602063465
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 8539.891116554329
# force on support right 7812.913997357123
# max supported force 27706.028034169074
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 12150.14513585744
# force on support right 10283.727710135661
# max supported force 21212.427713660698
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 15623.24080634775
# force on support right 12797.06305060812
# max supported force 16760.436712028208
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  10
# checking if support withstands tension
# force on support left 18895.826099725287
# force on support right 15311.75043798668
# max supported force 13575.953736742847
# Support withstands tension: False
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# segment is infesible
# segment is infesible
# raising height to  6
# ...
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  12
# checking if support withstands tension
# force on support left 21059.478945772415
# force on support right 19256.380611461766
# max supported force 79372.72095797055
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  13
# checking if support withstands tension
# force on support left 22615.033786902346
# force on support right 21021.9189820078
# max supported force 67631.19418904
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  14
# checking if support withstands tension
# force on support left 24138.03515046207
# force on support right 22800.24417821895
# max supported force 58314.65213238653
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# segment is infesible
# raising height to  6
# checking if support withstands tension
# force on support left 6327.106459720594
# force on support right 6349.357446549082
# max supported force 1718920.9155453339
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 3777.6108301869945
# force on support right 3605.569719097755
# max supported force 1262880.6726455514
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 3381.2100486691966
# force on support right 3033.879582298457
# max supported force 966893.0149942503
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 4805.416282382067
# force on support right 3529.033389983668
# max supported force 763964.8513534818
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  10
# checking if support withstands tension
# force on support left 6904.663451538332
# force on support right 4768.345923477854
# max supported force 618811.5295963202
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  11
# checking if support withstands tension
# force on support left 9146.49993450448
# force on support right 6326.270672641886
# max supported force 511414.4872696861
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  12
# checking if support withstands tension
# force on support left 11384.506344298545
# force on support right 8015.965909768882
# max supported force 429730.22888633347
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  13
# checking if support withstands tension
# force on support left 13571.535435245363
# force on support right 9765.605163418957
# max supported force 366160.6684001895
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  14
# checking if support withstands tension
# force on support left 15690.08870835395
# force on support right 11544.01662063969
# max supported force 315720.16816138785
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# segment is infesible
# raising height to  6
# checking if support withstands tension
# force on support left 3849.2731520708144
# force on support right 3144.9057426239783
# max supported force 678707.2357242806
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 6924.6820150798685
# force on support right 4909.572566189273
# max supported force 498642.0507362061
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 8790.44126406956
# force on support right 6939.123098518451
# max supported force 381772.82009490783
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 10711.224142502031
# force on support right 9205.094551790879
# max supported force 301647.6603219025
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  10
# checking if support withstands tension
# force on support left 12654.271190104548
# force on support right 11625.79664564656
# max supported force 244334.604860741
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  11
# checking if support withstands tension
# force on support left 14602.69461196649
# force on support right 14168.127770490508
# max supported force 201929.42550474463
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  12
# checking if support withstands tension
# force on support left 16546.490122345524
# force on support right 16814.479481134582
# max supported force 169676.80893107015
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  13
# checking if support withstands tension
# force on support left 18479.04862097473
# force on support right 19552.332147054058
# max supported force 144576.68926671066
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  14
# checking if support withstands tension
# force on support left 20395.646123873794
# force on support right 22370.372896145167
# max supported force 124660.51268405153
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# segment is infesible
# raising height to  6
# checking if support withstands tension
# force on support left 13772.257304307637
# force on support right 11642.798570344803
# max supported force 39054.37436457388
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 20466.961416838738
# force on support right 15685.749415938426
# max supported force 28693.009737237953
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 22794.848642905374
# force on support right 19612.140160662984
# max supported force 21968.08558007281
# Support withstands tension: False
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# segment is infesible
# raising height to  6
# checking if support withstands tension
# force on support left 14100.83319249916
# force on support right 11884.378367551184
# max supported force 33038.30318895453
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 21535.037999238033
# force on support right 16339.249515323043
# max supported force 24273.03907759925
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 23947.02952312078
# force on support right 20660.12468759377
# max supported force 18584.045543786924
# Support withstands tension: False
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# segment is infesible
# raising height to  6
# checking if support withstands tension
# force on support left 17277.89509043896
# force on support right 14880.157327016126
# max supported force 29258.38678153538
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 25574.92986969265
# force on support right 19752.73120774245
# max supported force 21495.95763541375
# Support withstands tension: False
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# segment is infesible
# raising height to  6
# checking if support withstands tension
# force on support left 7442.501040701625
# force on support right 5974.406676138588
# max supported force 1216.4973410753876
# Support withstands tension: False
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# segment is infesible
# raising height to  6
# checking if support withstands tension
# force on support left 17036.322446667204
# force on support right 14600.950029933349
# max supported force 35722.000071440096
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 27385.956526695314
# force on support right 20467.20569701248
# max supported force 26244.73474636415
# Support withstands tension: False
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# segment is infesible
# raising height to  6
# checking if support withstands tension
# force on support left 17087.63644027035
# force on support right 14668.01181131485
# max supported force 88226.13627124904
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 27367.220433420298
# force on support right 20492.725144200373
# max supported force 64819.20215846868
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 29918.0629243235
# force on support right 26353.04543654607
# max supported force 49627.20165257758
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 32380.586090292956
# force on support right 32479.479833061414
# max supported force 39211.61612055513
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  10
# checking if support withstands tension
# force on support left 34770.123362430604
# force on support right 38705.965899203926
# max supported force 31761.409057649656
# Support withstands tension: False
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# segment is infesible
# raising height to  6
# checking if support withstands tension
# force on support left 13318.968130960991
# force on support right 9725.763046441303
# max supported force 213231.0761837844
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 49875.967025259866
# force on support right 27557.67343097753
# max supported force 156659.5661758416
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 51995.335706753634
# force on support right 47255.79238512152
# max supported force 119942.48035337873
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 53647.08999305797
# force on support right 63406.42649572862
# max supported force 94769.36719279307
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  10
# checking if support withstands tension
# force on support left 54995.22159147287
# force on support right 74158.63707216333
# max supported force 76763.18742616239
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  11
# checking if support withstands tension
# force on support left 56173.52618944061
# force on support right 80928.49618867875
# max supported force 63440.65076542346
# Support withstands tension: False
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# segment is infesible
# no feasible left supports found
# no suitable supports found
# 60  after checking for height obstructions
# we have n lines:  60

# %%
forest_area_3.compute_line_costs()

# %%
# store forest_area_3
# output = open("forest_area_3.pkl", "wb")
# pickle.dump(forest_area_3, output)

# # new forest area as of march
# output = open("forest_area_3_03_2024.pkl", "wb")
# pickle.dump(forest_area_3, output)

# %%
# # load the forest_area_3
# pkl_file = open("forest_area_3.pkl", "rb")
# forest_area_3 = pickle.load(pkl_file)

# %% [markdown]
# #### Create the optimization

# %%
from src.main import optimization_execution


def optimization_main_loop(forest_area_gdf):
    """Main loop for the optimization algorithm"""

    optimization_result_list = []
    model_list = []

    # first the basis optimization
    print("Starting basis optimization")
    (
        model_list,
        optimization_result_list,
    ) = optimization_execution.soo_optimization_augmecon(
        model_list, optimization_result_list, forest_area_gdf
    )

    # then the manual weights optimization
    print("Starting manual weights optimization")
    optimization_result_list = optimization_execution.soo_optimization_manual_weights(
        model_list, optimization_result_list, forest_area_gdf
    )

    # then the NSGA II optimization
    print("Starting NSGA II optimization")
    optimization_result_list = optimization_execution.nsga_optimization(
        model_list, optimization_result_list, forest_area_gdf
    )

    # create a result df to save the results
    results_df = optimization_execution.create_results_df(
        optimization_result_list, model_list[0], forest_area_gdf
    )

    # create ranges for the different objectives based on the results
    (
        ecological_range,
        ecological_step,
        ergonomics_range,
        ergonomics_step,
    ) = optimization_execution.compute_augmecon_ranges(results_df)

    # conduct the augmecon optimization
    print("Starting augmecon optimization")
    optimization_result_list = optimization_execution.augmecon_optimization(
        optimization_result_list,
        ecological_range,
        ecological_step,
        ergonomics_range,
        ergonomics_step,
        forest_area_gdf,
    )

    # and finally the expert layout optimization
    print("Starting expert layout optimization")
    optimization_result_list = optimization_execution.expert_layout_optimization(
        optimization_result_list, model_list[0], forest_area_gdf
    )

    # and final result list
    results_df = optimization_execution.create_results_df(
        optimization_result_list, model_list[0], forest_area_gdf
    )

    return results_df, optimization_result_list, model_list


results_df, optimization_result_list, model_list = optimization_main_loop(
    forest_area_3_03_2024
)
# Out:
# Starting basis optimization
# Starting with objective 0
# test
# Starting with objective 1
# test
# Starting with objective 2
# test
# Starting manual weights optimization
# /home/carlo/GitHub/MultiObjectOptimizationCableYarding/moo_env/lib/python3.10/site-packages/pulp/pulp.py:1704: UserWarning:
#
# Overwriting previously set objective.
# test
# Starting NSGA II optimization
# /home/carlo/GitHub/MultiObjectOptimizationCableYarding/src/main/classes_mo_optimization.py:425: RuntimeWarning:
#
# overflow encountered in exp
# Profit baseline is 59720.0252023981
# Starting augmecon optimization
# test
# i should be : 2005.4730296154075
# test
# i is : 2005.4730296154075
#           j should be: 1838.3885010354002
# test
#           j is :  1838.3885010354002
#           cost is : 5549.491651928141
# /home/carlo/GitHub/MultiObjectOptimizationCableYarding/moo_env/lib/python3.10/site-packages/pulp/pulp.py:1704: UserWarning:
#
# Overwriting previously set objective.
#           j should be: 1738.50474389064
# test
#           j is :  1705.607944775204
#           cost is : 5654.627406889995
# /home/carlo/GitHub/MultiObjectOptimizationCableYarding/moo_env/lib/python3.10/site-packages/pulp/pulp.py:1704: UserWarning:
#
# Overwriting previously set objective.
#           j should be: 1638.6209867458797
# test
#           j is :  1522.4568789241735
#           cost is : 6048.722692788812
# /home/carlo/GitHub/MultiObjectOptimizationCableYarding/moo_env/lib/python3.10/site-packages/pulp/pulp.py:1704: UserWarning:
#
# Overwriting previously set objective.
#          skipping j_bypass: 1
#           j should be: 1438.8534724563592
# test
#           j is :  1437.8534724563592
#           cost is : 6723.137399746149
# /home/carlo/GitHub/MultiObjectOptimizationCableYarding/moo_env/lib/python3.10/site-packages/pulp/pulp.py:1704: UserWarning:
#
# Overwriting previously set objective.
# i should be : 1868.3574462303707
# test
# i is : 1859.5347999391151
#           j should be: 1838.3885010354002
# test
#           j is :  1705.607944775204
#           cost is : 5654.627406889995
# /home/carlo/GitHub/MultiObjectOptimizationCableYarding/moo_env/lib/python3.10/site-packages/pulp/pulp.py:1704: UserWarning:
#
# Overwriting previously set objective.
#          skipping j_bypass: 1
#           j should be: 1638.6209867458797
# test
#           j is :  1522.4568789241735
#           cost is : 6048.722692788812
# /home/carlo/GitHub/MultiObjectOptimizationCableYarding/moo_env/lib/python3.10/site-packages/pulp/pulp.py:1704: UserWarning:
#
# Overwriting previously set objective.
#          skipping j_bypass: 1
#           j should be: 1438.8534724563592
# test
#           j is :  1437.8534724563592
#           cost is : 6723.137399746149
# /home/carlo/GitHub/MultiObjectOptimizationCableYarding/moo_env/lib/python3.10/site-packages/pulp/pulp.py:1704: UserWarning:
#
# Overwriting previously set objective.
# i should be : 1731.2418628453338
# test
# i is : 1677.2656177566137
#           j should be: 1838.3885010354002
# test
#           j is :  1558.011917966088
#           cost is : 6230.380234325448
# /home/carlo/GitHub/MultiObjectOptimizationCableYarding/moo_env/lib/python3.10/site-packages/pulp/pulp.py:1704: UserWarning:
#
# Overwriting previously set objective.
#          skipping j_bypass: 2
#           j should be: 1538.7372296011195
# test
#           j is :  1522.4568789241735
#           cost is : 6048.722692788812
# /home/carlo/GitHub/MultiObjectOptimizationCableYarding/moo_env/lib/python3.10/site-packages/pulp/pulp.py:1704: UserWarning:
#
# Overwriting previously set objective.
#           j should be: 1438.8534724563592
# test
#           j is :  1437.8534724563592
#           cost is : 6723.137399746149
# /home/carlo/GitHub/MultiObjectOptimizationCableYarding/moo_env/lib/python3.10/site-packages/pulp/pulp.py:1704: UserWarning:
#
# Overwriting previously set objective.
# i should be : 1594.1262794602967
# test
# i is : 1501.2719154350577
#           j should be: 1838.3885010354002
# test
#           j is :  1496.0639815025615
#           cost is : 6657.316714498004
# /home/carlo/GitHub/MultiObjectOptimizationCableYarding/moo_env/lib/python3.10/site-packages/pulp/pulp.py:1704: UserWarning:
#
# Overwriting previously set objective.
#          skipping j_bypass: 3
#           j should be: 1438.8534724563592
# test
#           j is :  1437.8534724563592
#           cost is : 6723.137399746149
# /home/carlo/GitHub/MultiObjectOptimizationCableYarding/moo_env/lib/python3.10/site-packages/pulp/pulp.py:1704: UserWarning:
#
# Overwriting previously set objective.
# i should be : 1457.0106960752598
# test
# i is : 1456.0106960752598
#           j should be: 1838.3885010354002
# test
#           j is :  1437.8534724563592
#           cost is : 6930.620571582298
# /home/carlo/GitHub/MultiObjectOptimizationCableYarding/moo_env/lib/python3.10/site-packages/pulp/pulp.py:1704: UserWarning:
#
# Overwriting previously set objective.
#          skipping j_bypass: 4
# Starting expert layout optimization
# Profit baseline is 54069.27979111956

# %%
# results_df = optimization_execution.create_results_df(
#     optimization_result_list, model_list[0], forest_area_3_03_2024
# )
# Out:
# Profit baseline is 54069.27979111956

# %%
# optimization_results = [results_df, optimization_result_list, model_list]
# # store optimization_results
# output = open("optimization_results_03_2024.pkl", "wb")
# pickle.dump(optimization_results, output, protocol=4)

# %%
# # load the optimization_results
# pkl_file = open("optimization_results.pkl", "rb")
# optimization_results = pickle.load(pkl_file)
# results_df, optimization_result_list, model_list = optimization_results

# %%
# # and the forest_area_3
# pkl_file = open("forest_area_3.pkl", "rb")
# forest_area_3 = pickle.load(pkl_file)

# %% [markdown]
# #### Plotting

# %%
# load the optimization_results
pkl_file = open("optimization_results.pkl", "rb")
optimization_results = pickle.load(pkl_file)
results_df, optimization_result_list, model_list = optimization_results

# and the forest_area_3
pkl_file = open("forest_area_3_03_2024.pkl", "rb")
forest_area_3_03_2024 = pickle.load(pkl_file)
forest_area_3 = forest_area_3_03_2024

from src.main import global_vars

kdtree = global_vars.init(forest_area_3.height_gdf)

# %%
from ipywidgets import VBox, HBox
from src.main.interface import interactive_cr_selection

(
    interactive_layout,
    current_cable_roads_table_figure,
    layout_overview_table_figure,
    pareto_frontier,
    pareto_explanation_widget,
    move_left_button,
    move_right_button,
    reset_all__CRs_button,
    add_to_layout_button,
    reset_comparison_button,
    view_in_3d_button,
    dropdown_menu,
    layout_comparison_figure,
    layout_3d_scatter_plot,
) = interactive_cr_selection(
    forest_area_3, model_list, optimization_result_list, results_df
)


interface = VBox(
    [
        HBox(
            [
                move_left_button,
                move_right_button,
                reset_all__CRs_button,
                add_to_layout_button,
                reset_comparison_button,
                dropdown_menu,
                view_in_3d_button,
            ]
        ),
        HBox(
            [
                interactive_layout,
                layout_comparison_figure,
            ]
        ),
        HBox(
            [
                VBox(
                    [
                        pareto_frontier,
                        pareto_explanation_widget,
                    ]
                ),
                VBox(
                    [
                        current_cable_roads_table_figure,
                        layout_overview_table_figure,
                    ]
                ),
            ]
        ),
        layout_3d_scatter_plot,
    ]
)

display(interface)
# Out:
# /home/carlo/GitHub/MultiObjectOptimizationCableYarding/src/main/interface.py:386: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# VBox(children=(HBox(children=(Button(description='<-', style=ButtonStyle()), Button(description='->', style=Bu…
