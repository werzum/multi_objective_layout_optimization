# %% [markdown]
# # Loading Tests

# %%
from src import helper_functions_tests, test_cable_roads
from importlib import reload

# %%
reload(helper_functions_tests)
line_gdf, tree_gdf, height_gdf = helper_functions_tests.set_up_gdfs()

# %%
cable_road = helper_functions_tests.load_cable_road(line_gdf, height_gdf, 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 cable_road = helper_functions_tests.load_cable_road(line_gdf, height_gdf, 0)
#
# NameError: name 'helper_functions_tests' is not defined

# %%
cable_road.start_point_height
# Out:
# -1.6448

# %%
cable_road.end_point_height
# Out:
# -72.9654

# %%
line_gdf
# Out:
# Index(['geometry', 'line_candidates', 'slope_deviation',
#        'tree_anchor_support_trees', 'possible_anchor_triples',
#        'max_holding_force', 'number_of_supports', 'location_of_int_supports',
#        'current_tension', 'angle_between_supports', 'line_length'],
#       dtype='object')

# %%
reload(test_cable_roads)
test_cable_roads.test_supported_cable_road(line_gdf, height_gdf)
# Out:
# Cable road created from line:  (-29.880646898378075, -8.757599103801436) to  (-106.0132132, 89.40781657)
# checking if no collisions overall line
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[35], line 2
#       1 reload(test_cable_roads)
# ----> 2 test_cable_roads.test_supported_cable_road(line_gdf, height_gdf)
#
# File ~/GitHub/MultiObjectOptimizationCableYarding/src/test_cable_roads.py:53, in test_supported_cable_road(line_gdf, height_gdf)
#      36 (
#      37     max_supported_forces,
#      38     anchor_triplets,
#    (...)
#      49     0
#      50 ]
#      52 mechanical_computations.check_if_no_collisions_cable_road(cable_road)
# ---> 53 assert cable_road.no_collisions == True
#      55 tower_and_anchors_hold = (
#      56     mechanical_computations.check_if_tower_and_anchor_trees_hold(
# ...

# %%
line_gdf
# Out:
#                                          geometry  \
# 0    LINESTRING (-29.881 -8.758, -106.013 89.408)
# 1     LINESTRING (-28.098 -7.854, -96.731 98.533)
# 2     LINESTRING (-26.335 -6.909, -83.485 95.870)
# 3    LINESTRING (-26.335 -6.909, -83.968 102.835)
# 4    LINESTRING (-26.335 -6.909, -89.621 107.525)
# 5    LINESTRING (-26.335 -6.909, -83.375 106.991)
# 6    LINESTRING (-26.335 -6.909, -85.631 113.164)
# 7    LINESTRING (-26.335 -6.909, -79.218 104.897)
# 8    LINESTRING (-26.335 -6.909, -87.313 111.509)
# 9    LINESTRING (-24.572 -5.964, -74.378 104.487)
# 10   LINESTRING (-24.572 -5.964, -72.969 113.723)
# 11   LINESTRING (-24.572 -5.964, -78.823 117.613)
# 12   LINESTRING (-24.572 -5.964, -74.757 104.701)
# 13    LINESTRING (-22.810 -5.019, -93.901 85.119)
# 14    LINESTRING (-22.810 -5.019, -97.022 88.550)
# 15   LINESTRING (-22.810 -5.019, -107.911 82.709)
# 16   LINESTRING (-22.810 -5.019, -67.582 122.305)
# 17   LINESTRING (-22.810 -5.019, -65.916 122.596)
# ...
