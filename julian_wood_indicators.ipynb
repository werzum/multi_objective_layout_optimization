# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


sns.set(rc={'figure.figsize':(14,10)})

# %%
with open("1_3.csv") as file:
        table_1_3 = pd.read_csv(file)

# %%
table_1_3
# Out:
#         ID Region  Country  Unnamed: 3        LEGENDE Unnamed: 5  \
# 0    17_01      c       21         NaN         Region       Code
# 1    17_02      e       20         NaN         Africa          a
# 2    17_03      c       15         NaN   Central Asia          b
# 3    17_04      e       20         NaN         Europe          c
# 4    17_05      f       44         NaN  Latin America          d
# ..     ...    ...      ...         ...            ...        ...
# 341  21_67      e       20         NaN            NaN        NaN
# 342  21_68      d        5         NaN            NaN        NaN
# 343  21_70      d        5         NaN            NaN        NaN
# 344  21_71      c       32         NaN            NaN        NaN
# 345  22_01      f       44         NaN            NaN        NaN
#
#                  Unnamed: 6 Unnamed: 7
# 0                  Country        Code
# 1                 Argentina          1
# 2                 Australia          2
# ...

# %%
unique_country = table_1_3["Country"].value_counts(sort=False)
country_names = table_1_3["Unnamed: 6"].iloc[1:45]

fig, ax = plt.subplots(figsize=(12, 6))
sns.barplot(country_names, unique_country.values, ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.show()
# x = np.arange(len(country_names))  # the label locations
# fig, ax = plt.subplots()
# ax.bar(unique_country.values)
# Out:
# /home/carlo/GitHub/MultiObjectOptimizationCableYarding/moo_env/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
tips = sns.load_dataset("tips")

fig, ax = plt.subplots(figsize=(12, 6))
sns.barplot(x="Country", y="Amount mentioned", country_names, unique_country.values, ax=ax)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.show()
